# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit the data set from our last studio. If you recall, California farmers were looking for advice on growing pumpkins. We will use the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# A **terminal market** is a central site, often in a metropolitan area, that serves as an assembly and trading place for commodities. Terminal markets for agricultural commodities are usually at or near major transportation hubs. [Definition Source](https://en.wikipedia.org/wiki/Terminal_market#:~:text=A%20terminal%20market%20is%20a,or%20near%20major%20transportation%20hubs)
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np
baltimore = pd.read/Users/megancampbell/desktop/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/baltimore_9-24-2016_9-30-2017.csv") 
boston = pd._csv(r"read_csv(r"/Users/megancampbell/desktop/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/boston_9-24-2016_9-30-2017.csv")
ny = pd.read_csv(r"/Users/megancampbell/desktop/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/new-york_9-24-2016_9-30-2017.csv")
philly = pd.read_csv(r"/Users/megancampbell/desktop/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/philadelphia_9-24-2016_9-30-2017.csv")
# Out:
#   Commodity Name  City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 1       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 2       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  04/29/2017        270       280.0  ...    NaN          NaN
# 1    NaN  05/06/2017        270       280.0  ...    NaN          NaN
# 2    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 3    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 4    NaN  11/05/2016         90       100.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 1          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 2          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data related to San Francisco. Pull up your notebook from the last lesson and use it as a reference to clean up these new dataframes.

# %%
# Clean your data here!
# baltimore = baltimore.drop(["Type", "Grade", "Origin District", "Environment", "Quality", "Condition", "Appearance", "Storage", "Crop", "Trans Mode"], axis=1) 
# boston = boston.drop(["Type", "Grade", "Origin District", "Environment", "Quality", "Condition", "Appearance", "Storage", "Crop", "Trans Mode"], axis=1) 
# ny = ny.drop(["Type", "Grade", "Origin District", "Environment", "Quality", "Condition", "Appearance", "Storage", "Crop", "Trans Mode"], axis=1) 
# philly = philly.drop(["Type", "Grade", "Origin District", "Environment", "Quality", "Condition", "Appearance", "Storage", "Crop", "Trans Mode"], axis=1) 

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# baltimore["Repack"] = baltimore["Repack"].replace({"N":False, "E":True})
# boston["Repack"] = boston["Repack"].replace({"N":False, "E":True})
# ny["Repack"] = ny["Repack"].replace({"N":False, "E":True})
# philly["Repack"] = philly["Repack"].replace({"N":False, "E":True})

display(philly.head())
display(boston.head())
display(ny.head())
display(philly.head())
# Out:
#   Commodity Name     City Name       Package      Variety Sub Variety  \
# 0       PUMPKINS  PHILADELPHIA  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  PHILADELPHIA  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  PHILADELPHIA  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  PHILADELPHIA  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  PHILADELPHIA  36 inch bins  HOWDEN TYPE         NaN
#
#          Date  Low Price  High Price  Mostly Low  Mostly High        Origin  \
# 0  09/16/2017        140         150         140          150  PENNSYLVANIA
# 1  09/24/2016        150         150         150          150      NEW YORK
# 2  09/24/2016        150         150         150          150      NEW YORK
# 3  09/24/2016        150         160         150          160  PENNSYLVANIA
# 4  10/01/2016        140         140         140          140    NEW JERSEY
#
#   Item Size  Color Unit of Sale  Repack
# 0       lge    NaN          NaN   False
# 1   med-lge    NaN          NaN   False
# 2       med    NaN          NaN   False
# 3       lge    NaN          NaN   False
# 4   med-lge    NaN          NaN   False
#   Commodity Name City Name       Package      Variety Sub Variety        Date  \
# 0       PUMPKINS    BOSTON  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
# 1       PUMPKINS    BOSTON  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
# 2       PUMPKINS    BOSTON  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
# 3       PUMPKINS    BOSTON  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
# 4       PUMPKINS    BOSTON  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
#
#    Low Price  High Price  Mostly Low  Mostly High  Origin Item Size   Color  \
# 0        160         200         165          165  CANADA     exjbo  ORANGE
# 1        160         200         165          165  CANADA       jbo  ORANGE
# 2        160         200         165          165  CANADA      xlge  ORANGE
# 3        160         200         165          165  CANADA      xlge  ORANGE
# 4        160         180         165          165  CANADA       lge  ORANGE
#
#   Unit of Sale  Repack
# 0          NaN   False
# 1          NaN   False
# 2          NaN   False
# 3          NaN   False
# 4          NaN   False
#   Commodity Name City Name       Package      Variety Sub Variety        Date  \
# 0       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
# 1       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
# 2       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
# 3       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
# 4       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE         NaN  09/24/2016
#
#    Low Price  High Price  Mostly Low  Mostly High      Origin Item Size Color  \
# 0        150         170         150          170    MICHIGAN      xlge   NaN
# 1        150         170         150          170    MICHIGAN       lge   NaN
# 2        130         150         130          150  NEW JERSEY      xlge   NaN
# 3        130         150         130          150  NEW JERSEY       lge   NaN
# 4        120         140         120          140    NEW YORK   med-lge   NaN
#
#   Unit of Sale  Repack
# 0          NaN   False
# 1          NaN   False
# 2          NaN   False
# 3          NaN   False
# 4          NaN   False
#   Commodity Name     City Name       Package      Variety Sub Variety  \
# 0       PUMPKINS  PHILADELPHIA  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  PHILADELPHIA  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  PHILADELPHIA  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  PHILADELPHIA  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  PHILADELPHIA  36 inch bins  HOWDEN TYPE         NaN
#
#          Date  Low Price  High Price  Mostly Low  Mostly High        Origin  \
# 0  09/16/2017        140         150         140          150  PENNSYLVANIA
# 1  09/24/2016        150         150         150          150      NEW YORK
# 2  09/24/2016        150         150         150          150      NEW YORK
# 3  09/24/2016        150         160         150          160  PENNSYLVANIA
# 4  10/01/2016        140         140         140          140    NEW JERSEY
#
#   Item Size  Color Unit of Sale  Repack
# 0       lge    NaN          NaN   False
# 1   med-lge    NaN          NaN   False
# 2       med    NaN          NaN   False
# 3       lge    NaN          NaN   False
# 4   med-lge    NaN          NaN   False

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of **unit of sale** in the Northeast region?
# 2. For each region, what is the average number of pumpkins per variety that came into terminal markets for the year?

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
